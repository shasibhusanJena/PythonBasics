# %%
import pandas as pd

# %%
data_frame = pd.read_csv('C:/Users/shjena/Downloads/2023-10-30-cdp_person_seminar.csv', sep='\t')

# %%
#displaying first five rows
display(data_frame.head())

#displaying last five rows
display(data_frame.tail())
# Out:
#    Geschäftspartnernummer (GP)  Bestellberater-Nr. (VBu)  Id. Person  \
# 0                          249                     18735         589
# 1                          249                     18735         591
# 2                          249                     18735         591
# 3                          249                     18735         591
# 4                          249                     18735         591
#
#   Kennz. Vertriebs relevante Leistung  Nummer externe Produktgruppe  \
# 0                                   J                            17
# 1                                   J                            17
# 2                                   J                            17
# 3                                   J                            17
# 4                                   J                            17
#
#   Langbezeichnung externe Produktgruppe  Nummer externes Produkt  \
# 0                                Wissen                     3800
# 1                                Wissen                     2612
# 2                                Wissen                     2612
# 3                                Wissen                     2612
# 4                                Wissen                     2612
#
#                     Langbezeichnung externes Produkt  Artikelnummer  \
# 0                       Fach- und Managementseminare          70895
# 1  Dialogseminare online Betriebliches Rechnungsw...          77339
# 2  Dialogseminare online Betriebliches Rechnungsw...          77339
# 3  Dialogseminare online Betriebliches Rechnungsw...          77340
# 4  Dialogseminare online Betriebliches Rechnungsw...          77340
#
#    Nummer Leistungsart  ... Bezeichnung Art Artikelnummer  \
# 0                    5  ...           sonstige Leistungen
# 1                    5  ...           Schulungsleistungen
# 2                    5  ...           Schulungsleistungen
# 3                    5  ...           Schulungsleistungen
# 4                    5  ...           Schulungsleistungen
#
#    Nummer Strukturderivat  Veranstaltungsklasse  Veranstaltungsklasse kurz  \
# 0                   204.0       Präsenzseminare                         AW
# 1                   203.0  Onlineseminare Adobe                         DO
# 2                   203.0  Onlineseminare Adobe                         DO
# 3                   204.0  Onlineseminare Adobe                         DO
# 4                   204.0  Onlineseminare Adobe                         DO
#
#   Nummer verarbeitendes System  Bezeichnung verarbeitendes System  \
# 0                            2           Kolleg-Seminarverwaltung
# 1                            2           Kolleg-Seminarverwaltung
# 2                            2           Kolleg-Seminarverwaltung
# 3                            2           Kolleg-Seminarverwaltung
# 4                            2           Kolleg-Seminarverwaltung
#
#   ID Veranstaltung (VBu) Tag Veranstaltungsbuchung  Lfd. Nummer (VBu)  \
# 0                 525312                06.02.2019           10578712
# 1                 557150                03.02.2021           10847609
# 2                 565103                15.12.2021           10972527
# 3                 555951                01.02.2021           10847166
# 4                 568252                15.12.2021           10972086
#
#                              Langbezeichnung Artikel
# 0  Jahresabschluss und Steuererklärungen der Pers...
# 1                         Jahresabschluss einer GmbH
# 2                         Jahresabschluss einer GmbH
# 3  Jahresabschluss und Steuererklärungen der Pers...
# 4  Jahresabschluss und Steuererklärungen der Pers...
#
# [5 rows x 24 columns]
#         Geschäftspartnernummer (GP)  Bestellberater-Nr. (VBu)  Id. Person  \
# 635330                      1827313                    568529     5510723
# 635331                      1827313                    568529     7756980
# 635332                      1827313                    568529     7756980
# 635333                      1827313                    568529     7756980
# 635334                      1827313                    568529     9540140
#
#        Kennz. Vertriebs relevante Leistung  Nummer externe Produktgruppe  \
# 635330                                   J                            17
# 635331                                   J                            17
# 635332                                   J                            17
# 635333                                   N                            17
# 635334                                   J                            17
#
#        Langbezeichnung externe Produktgruppe  Nummer externes Produkt  \
# 635330                                Wissen                     2619
# 635331                                Wissen                     2618
# 635332                                Wissen                     2618
# 635333                                Wissen                     2618
# 635334                                Wissen                     2618
#
#                     Langbezeichnung externes Produkt  Artikelnummer  \
# 635330  Dialogseminare online Steuern und Expertisen          78552
# 635331      Dialogseminare online Personalwirtschaft          78589
# 635332      Dialogseminare online Personalwirtschaft          78647
# 635333      Dialogseminare online Personalwirtschaft          78626
# 635334      Dialogseminare online Personalwirtschaft          73314
#
#         Nummer Leistungsart  ... Bezeichnung Art Artikelnummer  \
# 635330                    5  ...           Schulungsleistungen
# 635331                    5  ...           Schulungsleistungen
# 635332                    5  ...           Schulungsleistungen
# 635333                    5  ...           Schulungsleistungen
# 635334                    5  ...           Schulungsleistungen
#
#         Nummer Strukturderivat  Veranstaltungsklasse  \
# 635330                   204.0  Onlineseminare Adobe
# 635331                   203.0  Onlineseminare Adobe
# 635332                   203.0  Onlineseminare Adobe
# 635333                   203.0  Onlineseminare Adobe
# 635334                   203.0  Onlineseminare Adobe
#
#         Veranstaltungsklasse kurz Nummer verarbeitendes System  \
# 635330                         DO                            2
# 635331                         DO                            2
# 635332                         DO                            2
# 635333                         DO                            2
# 635334                         DO                            2
#
#         Bezeichnung verarbeitendes System ID Veranstaltung (VBu)  \
# 635330           Kolleg-Seminarverwaltung                 578910
# 635331           Kolleg-Seminarverwaltung                 579357
# 635332           Kolleg-Seminarverwaltung                 584007
# 635333           Kolleg-Seminarverwaltung                 580647
# 635334           Kolleg-Seminarverwaltung                 598819
#
#        Tag Veranstaltungsbuchung  Lfd. Nummer (VBu)  \
# 635330                24.05.2022           11019872
# 635331                12.05.2022           11016901
# 635332                19.09.2022           11056209
# 635333                04.07.2022           11031012
# 635334                29.09.2023           11201399
#
#                                   Langbezeichnung Artikel
# 635330  Grundsteuerreform - Bundesmodell und Ländermod...
# 635331  Beschäftigung von Flüchtlingen - Schwerpunkt: ...
# 635332  Abschlussprüfung zum Kurzarbeitergeld - DATEV ...
# 635333  Energiepreispauschale und Steuerentlastung in ...
# 635334  Jahreswechsel in der Lohnabrechnung mit DATEV ...
#
# [5 rows x 24 columns]

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 635335 entries, 0 to 635334
# Data columns (total 24 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   Geschäftspartnernummer (GP)            635335 non-null  int64
#  1   Bestellberater-Nr. (VBu)               635335 non-null  int64
#  2   Id. Person                             635335 non-null  int64
#  3   Kennz. Vertriebs relevante Leistung    635335 non-null  object
#  4   Nummer externe Produktgruppe           635335 non-null  int64
#  5   Langbezeichnung externe Produktgruppe  635335 non-null  object
#  6   Nummer externes Produkt                635335 non-null  int64
#  7   Langbezeichnung externes Produkt       635335 non-null  object
#  8   Artikelnummer                          635335 non-null  int64
#  9   Nummer Leistungsart                    635335 non-null  int64
#  10  Bezeichnung Leistungsart               635335 non-null  object
#  11  Nummer Artikeltyp                      635335 non-null  int64
#  12  Bezeichnung Artikeltyp                 635335 non-null  object
#  13  Nummer Art Artikelnummer               635335 non-null  int64
#  14  Bezeichnung Art Artikelnummer          635335 non-null  object
#  15  Nummer Strukturderivat                 581372 non-null  float64
#  16  Veranstaltungsklasse                   635335 non-null  object
#  17  Veranstaltungsklasse kurz              635335 non-null  object
#  18  Nummer verarbeitendes System           635335 non-null  int64
#  19  Bezeichnung verarbeitendes System      635335 non-null  object
#  20  ID Veranstaltung (VBu)                 635335 non-null  int64
#  21  Tag Veranstaltungsbuchung              635335 non-null  object
#  22  Lfd. Nummer (VBu)                      635335 non-null  int64
#  23  Langbezeichnung Artikel                635335 non-null  object
# dtypes: float64(1), int64(12), object(11)
# memory usage: 116.3+ MB

# %%
data_frame.isnull().sum()
# Out:
# Geschäftspartnernummer (GP)                  0
# Bestellberater-Nr. (VBu)                     0
# Id. Person                                   0
# Kennz. Vertriebs relevante Leistung          0
# Nummer externe Produktgruppe                 0
# Langbezeichnung externe Produktgruppe        0
# Nummer externes Produkt                      0
# Langbezeichnung externes Produkt             0
# Artikelnummer                                0
# Nummer Leistungsart                          0
# Bezeichnung Leistungsart                     0
# Nummer Artikeltyp                            0
# Bezeichnung Artikeltyp                       0
# Nummer Art Artikelnummer                     0
# Bezeichnung Art Artikelnummer                0
# Nummer Strukturderivat                   53963
# Veranstaltungsklasse                         0
# Veranstaltungsklasse kurz                    0
# Nummer verarbeitendes System                 0
# Bezeichnung verarbeitendes System            0
# ID Veranstaltung (VBu)                       0
# Tag Veranstaltungsbuchung                    0
# Lfd. Nummer (VBu)                            0
# Langbezeichnung Artikel                      0
# dtype: int64

# %%
# count all values in name column in ascending order
print(data_frame['Langbezeichnung externes Produkt'].value_counts(ascending=True))
# Out:
# DATEV DMS classic                                         67
# IT-Sourcing                                               80
# Eigenorganisation                                        146
# Dialogseminare online DATEV Anwalt                       219
# DATEVasp                                                 288
# Konsolidierung allgemein                                 340
# Dialogseminare online DATEV                              521
# Seminare für Anwender Abschlussprüfung                   540
# Seminare für Anwender Steuern und Expertisen             557
# Seminare für Anwender IT-Lösungen                        567
# Eigenorganisation comfort                                735
# Abschlussprüfung allgemein                               754
# Digitale Datenanalyse                                   1011
# Kammern/Verbände                                        1197
# DATEVkommunal                                           1343
# Seminare für Anwender Wirtschaftsberatung               1380
# Dialogseminare online Abschlussprüfung                  1881
# Anwalt                                                  1900
# SmartTransfer                                           2369
# DATEV-Bildungs-Partner                                  2634
# Consulting/Seminare/Workshop                            3709
# Dialogseminare online IT-Lösungen und Security          6602
# Seminare für Anwender Office-Management                 6653
# Dialogseminare online Wissensvermittlung                8576
# Dialogseminare online Office-Management                 9979
# Consulting allgemein                                   17381
# Dialogseminare online Steuern und Expertisen           17970
# Qualifizierungsangebote                                18168
# Seminare für Anwender Zusatzangebote                   19087
# DATEV Solution Partner                                 20129
# Fach- und Managementseminare                           22482
# Dialogseminare online Betriebliches Rechnungswesen     39156
# Dialogseminare online Geschäftsfeldübergreifend        41784
# Seminare für Anwender Betriebliches Rechnungswesen     55869
# Sonstiges                                              75395
# Seminare für Anwender Personalwirtschaft              109583
# Dialogseminare online Personalwirtschaft              144283
# Name: Langbezeichnung externes Produkt, dtype: int64

# %%
# Replace 'column_name' with the name of your specific column
column_to_search = 'Langbezeichnung externes Produkt'

# Count occurrences of 'abc' in the specified column
abc_count = (data_frame[column_to_search] == 'Qualifizierungsangebote').sum()

print(f"The count of 'abc' in '{column_to_search}' column is: {abc_count}")
# Out:
# The count of 'abc' in 'Langbezeichnung externes Produkt' column is: 18168
